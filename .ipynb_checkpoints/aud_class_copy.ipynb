# %% [markdown]
# # Exploratory Data Analysis of Audio data

# %%
import os

os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

import IPython.display as ipd

filepath = "UrbanSound8K/audio/fold1/51022-3-7-0.wav"
ipd.Audio(filepath)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

data, sample_rate = librosa.load(filepath)

plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)

# %%
# not recommended
import scipy.io.wavfile as wav

wave_sample_rate, wave_audio = wav.read(filepath)
print(wave_sample_rate)
print(wave_audio)

plt.figure(figsize=(12, 4))
plt.plot(wave_audio)
# Out:
# 44100
# [[-297  -77]
#  [-213   70]
#  [-312   12]
#  ...
#  [-346 -247]
#  [-354 -149]
#  [   4   63]]
# [<matplotlib.lines.Line2D at 0x2a38f6abaf0>,
#  <matplotlib.lines.Line2D at 0x2a38f6abb50>]

# %% [markdown]
# # Imbalance Dataset check

# %%
import pandas as pd

metadata = pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
metadata['class'].value_counts()
# Out:
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64

# %%
import seaborn as sns
# plt.figure(figsize=(10, 6))
# sns.countplot(metadata['class'])
# sns.displot expect Series, 1d-array, or list. as 1st argument, not whole!
sns.displot(metadata['class'])
plt.title("Count of records in each class")
plt.xticks(rotation="vertical")
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

mfccs = librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=8732)
print(mfccs.shape)
print(mfccs)
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.tight_layout()
plt.title('MFCC')
plt.show
# Out:
# (128, 47)
# [[-3.0183932e+02 -2.7739447e+02 -2.7112619e+02 ... -2.6081686e+02
#   -2.6547592e+02 -2.6674850e+02]
#  [ 4.0948402e+01  5.2450958e+01  5.8762852e+01 ...  7.2143188e+01
#    7.0564362e+01  6.3760544e+01]
#  [-6.1408592e+01 -6.2314140e+01 -5.4252296e+01 ... -5.3847221e+01
#   -5.1989395e+01 -4.8518467e+01]
#  ...
#  [ 2.1788597e+00  6.5383911e-02 -2.2843895e+00 ...  6.2255859e-03
#    1.1938820e+00  6.0923767e-01]
#  [ 2.1276989e+00 -6.9766426e-01 -1.3700542e+00 ... -1.2302589e+00
#    6.2242889e-01 -8.4534836e-01]
#  [-1.1442375e+00 -1.4918213e+00 -1.1013222e+00 ... -2.3859787e-01
#    5.7737350e-01 -3.3175468e-01]]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np


def features_extractor():
    #load the file (audio)
    audio, samp_rate = librosa.load(file_name, res_type='kaiser_fast')
    #we extract mfcc
    mfccs_features = librosa.feature.mfcc(y=audio, sr=samp_rate, n_mfcc=8732)
    #in order to find out scaled feature we do mean of transpose of value
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

#Now we need to extract the featured from all the audio files, so we use tqdm
from tqdm import tqdm

# Now we iterate through every audio file and extract features
# using Mel-Frequency Cepstral Coefficients (MFCC)
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath('UrbanSound8K/audio'),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    final_class_labels=row["class"]
    data=features_extractor()
    extracted_features.append([data,final_class_labels])
# Out:
# 3554it [03:06, 19.95it/s]C:\Users\ashva\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1323
#   return f(*args, **kwargs)
# 8324it [07:17, 25.09it/s]C:\Users\ashva\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1103
#   return f(*args, **kwargs)
# C:\Users\ashva\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=2048 is too small for input signal of length=1523
#   return f(*args, **kwargs)
# 8732it [07:38, 19.06it/s]

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature             class
# 0  [-217.35526, 70.22338, -130.38527, -53.282898,...          dog_bark
# 1  [-424.09818, 109.34077, -52.919525, 60.86475, ...  children_playing
# 2  [-458.79114, 121.38419, -46.52066, 52.00812, -...  children_playing
# 3  [-413.89984, 101.66371, -35.42945, 53.036358, ...  children_playing
# 4  [-446.60352, 113.68541, -52.402218, 60.302044,...  children_playing

# %% [markdown]
# # Train Test split

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# Split the dataset into independent and dependent dataset
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# Label Encoding -> Label Encoder
import tensorflow as tf
from tensorflow.keras.models import Model
import tensorflow.keras as keras
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

label_encoder=LabelEncoder()
y=to_categorical(label_encoder.fit_transform(y))

# Train Test Split
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=0)

# %% [markdown]
# # Audio Classification Model Creation

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# No of classes
num_labels=y.shape[1]

model: object=Sequential()

#first layer
model.add(Dense(1000))
model.add(Activation('relu'))
model.add(Dropout(0.25))

#second layer
model.add(Dense(2000))
model.add(Activation('relu'))
model.add(Dropout(0.5))

#third layer
model.add(Dense(1000))
model.add(Activation('relu'))
model.add(Dropout(0.25))

#final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# Compile the Model
model.compile(loss='categorical_crossentropy',metrics=['accuracy', 'Precision', 'Recall'],optimizer='adam')

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# Training my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime

num_epochs = 50
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='./audio_classification.hdf5', verbose=1, save_best_only=True)

start = datetime.now()

history = model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)

duration = datetime.now() - start

print("Training completed in time: ", duration)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 8s 33ms/step - loss: 3.2908 - accuracy: 0.3784 - precision: 0.4646 - recall: 0.2424 - val_loss: 1.2747 - val_accuracy: 0.5741 - val_precision: 0.8407 - val_recall: 0.3263
#
# Epoch 00001: val_loss improved from inf to 1.27471, saving model to .\audio_classification.hdf5
# Epoch 2/50
# 219/219 [==============================] - 7s 30ms/step - loss: 1.2399 - accuracy: 0.5832 - precision: 0.7419 - recall: 0.4472 - val_loss: 0.9525 - val_accuracy: 0.7012 - val_precision: 0.8929 - val_recall: 0.4917
#
# Epoch 00002: val_loss improved from 1.27471 to 0.95247, saving model to .\audio_classification.hdf5
# Epoch 3/50
# 219/219 [==============================] - 7s 30ms/step - loss: 0.9342 - accuracy: 0.7006 - precision: 0.8213 - recall: 0.5874 - val_loss: 0.7765 - val_accuracy: 0.7653 - val_precision: 0.9015 - val_recall: 0.5970
#
# Epoch 00003: val_loss improved from 0.95247 to 0.77649, saving model to .\audio_classification.hdf5
# Epoch 4/50
# 219/219 [==============================] - 6s 29ms/step - loss: 0.7697 - accuracy: 0.7436 - precision: 0.8523 - recall: 0.6537 - val_loss: 0.7186 - val_accuracy: 0.7659 - val_precision: 0.8446 - val_recall: 0.6966
#
# Epoch 00004: val_loss improved from 0.77649 to 0.71860, saving model to .\audio_classification.hdf5
# Epoch 5/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.6615 - accuracy: 0.7798 - precision: 0.8672 - recall: 0.7112 - val_loss: 0.5891 - val_accuracy: 0.8220 - val_precision: 0.9034 - val_recall: 0.7121
#
# Epoch 00005: val_loss improved from 0.71860 to 0.58909, saving model to .\audio_classification.hdf5
# Epoch 6/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.5751 - accuracy: 0.8143 - precision: 0.8826 - recall: 0.7545 - val_loss: 0.4842 - val_accuracy: 0.8443 - val_precision: 0.9127 - val_recall: 0.7659
#
# Epoch 00006: val_loss improved from 0.58909 to 0.48416, saving model to .\audio_classification.hdf5
# Epoch 7/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.5192 - accuracy: 0.8288 - precision: 0.8925 - recall: 0.7725 - val_loss: 0.5012 - val_accuracy: 0.8392 - val_precision: 0.8994 - val_recall: 0.7779
#
# Epoch 00007: val_loss did not improve from 0.48416
# Epoch 8/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.4878 - accuracy: 0.8332 - precision: 0.8897 - recall: 0.7875 - val_loss: 0.4569 - val_accuracy: 0.8517 - val_precision: 0.9171 - val_recall: 0.7979
#
# Epoch 00008: val_loss improved from 0.48416 to 0.45687, saving model to .\audio_classification.hdf5
# Epoch 9/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.4184 - accuracy: 0.8593 - precision: 0.9085 - recall: 0.8186 - val_loss: 0.4417 - val_accuracy: 0.8683 - val_precision: 0.9314 - val_recall: 0.8077
#
# Epoch 00009: val_loss improved from 0.45687 to 0.44173, saving model to .\audio_classification.hdf5
# Epoch 10/50
# 219/219 [==============================] - 7s 34ms/step - loss: 0.4232 - accuracy: 0.8621 - precision: 0.9094 - recall: 0.8220 - val_loss: 0.4855 - val_accuracy: 0.8592 - val_precision: 0.9046 - val_recall: 0.8140
#
# Epoch 00010: val_loss did not improve from 0.44173
# Epoch 11/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.3799 - accuracy: 0.8780 - precision: 0.9135 - recall: 0.8427 - val_loss: 0.4075 - val_accuracy: 0.8821 - val_precision: 0.9410 - val_recall: 0.8220
#
# Epoch 00011: val_loss improved from 0.44173 to 0.40745, saving model to .\audio_classification.hdf5
# Epoch 12/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.3514 - accuracy: 0.8817 - precision: 0.9214 - recall: 0.8547 - val_loss: 0.4277 - val_accuracy: 0.8735 - val_precision: 0.9190 - val_recall: 0.8317
#
# Epoch 00012: val_loss did not improve from 0.40745
# Epoch 13/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.3643 - accuracy: 0.8829 - precision: 0.9211 - recall: 0.8543 - val_loss: 0.5576 - val_accuracy: 0.8598 - val_precision: 0.9103 - val_recall: 0.8014
#
# Epoch 00013: val_loss did not improve from 0.40745
# Epoch 14/50
# 219/219 [==============================] - 8s 35ms/step - loss: 0.3416 - accuracy: 0.8850 - precision: 0.9165 - recall: 0.8581 - val_loss: 0.3740 - val_accuracy: 0.8901 - val_precision: 0.9421 - val_recall: 0.8380
#
# Epoch 00014: val_loss improved from 0.40745 to 0.37401, saving model to .\audio_classification.hdf5
# Epoch 15/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.3558 - accuracy: 0.8882 - precision: 0.9214 - recall: 0.8596 - val_loss: 0.4149 - val_accuracy: 0.8815 - val_precision: 0.9263 - val_recall: 0.8420
#
# Epoch 00015: val_loss did not improve from 0.37401
# Epoch 16/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2946 - accuracy: 0.9062 - precision: 0.9338 - recall: 0.8823 - val_loss: 0.3979 - val_accuracy: 0.8918 - val_precision: 0.9218 - val_recall: 0.8701
#
# Epoch 00016: val_loss did not improve from 0.37401
# Epoch 17/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.3260 - accuracy: 0.8949 - precision: 0.9266 - recall: 0.8690 - val_loss: 0.3544 - val_accuracy: 0.8952 - val_precision: 0.9408 - val_recall: 0.8558
#
# Epoch 00017: val_loss improved from 0.37401 to 0.35445, saving model to .\audio_classification.hdf5
# Epoch 18/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.3039 - accuracy: 0.9026 - precision: 0.9284 - recall: 0.8805 - val_loss: 0.3630 - val_accuracy: 0.9004 - val_precision: 0.9405 - val_recall: 0.8592
#
# Epoch 00018: val_loss did not improve from 0.35445
# Epoch 19/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.3280 - accuracy: 0.8985 - precision: 0.9266 - recall: 0.8743 - val_loss: 0.3872 - val_accuracy: 0.8958 - val_precision: 0.9332 - val_recall: 0.8718
#
# Epoch 00019: val_loss did not improve from 0.35445
# Epoch 20/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.2814 - accuracy: 0.9115 - precision: 0.9352 - recall: 0.8925 - val_loss: 0.3164 - val_accuracy: 0.9147 - val_precision: 0.9456 - val_recall: 0.8849
#
# Epoch 00020: val_loss improved from 0.35445 to 0.31638, saving model to .\audio_classification.hdf5
# Epoch 21/50
# 219/219 [==============================] - 7s 32ms/step - loss: 0.2650 - accuracy: 0.9174 - precision: 0.9403 - recall: 0.8955 - val_loss: 0.3282 - val_accuracy: 0.9067 - val_precision: 0.9297 - val_recall: 0.8930
#
# Epoch 00021: val_loss did not improve from 0.31638
# Epoch 22/50
# 219/219 [==============================] - 7s 31ms/step - loss: 0.2611 - accuracy: 0.9158 - precision: 0.9360 - recall: 0.9001 - val_loss: 0.3387 - val_accuracy: 0.9021 - val_precision: 0.9406 - val_recall: 0.8603
#
# Epoch 00022: val_loss did not improve from 0.31638
# Epoch 23/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.2445 - accuracy: 0.9220 - precision: 0.9426 - recall: 0.9048 - val_loss: 0.3854 - val_accuracy: 0.8998 - val_precision: 0.9291 - val_recall: 0.8849
#
# Epoch 00023: val_loss did not improve from 0.31638
# Epoch 24/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2609 - accuracy: 0.9227 - precision: 0.9442 - recall: 0.9042 - val_loss: 0.4579 - val_accuracy: 0.8855 - val_precision: 0.9073 - val_recall: 0.8632
#
# Epoch 00024: val_loss did not improve from 0.31638
# Epoch 25/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2850 - accuracy: 0.9144 - precision: 0.9344 - recall: 0.8989 - val_loss: 0.4017 - val_accuracy: 0.8952 - val_precision: 0.9220 - val_recall: 0.8798
#
# Epoch 00025: val_loss did not improve from 0.31638
# Epoch 26/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2917 - accuracy: 0.9167 - precision: 0.9371 - recall: 0.8965 - val_loss: 0.3316 - val_accuracy: 0.9084 - val_precision: 0.9400 - val_recall: 0.8706
#
# Epoch 00026: val_loss did not improve from 0.31638
# Epoch 27/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2583 - accuracy: 0.9234 - precision: 0.9433 - recall: 0.9052 - val_loss: 0.4026 - val_accuracy: 0.8935 - val_precision: 0.9181 - val_recall: 0.8729
#
# Epoch 00027: val_loss did not improve from 0.31638
# Epoch 28/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2107 - accuracy: 0.9320 - precision: 0.9483 - recall: 0.9164 - val_loss: 0.4073 - val_accuracy: 0.8952 - val_precision: 0.9224 - val_recall: 0.8706
#
# Epoch 00028: val_loss did not improve from 0.31638
# Epoch 29/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2731 - accuracy: 0.9195 - precision: 0.9384 - recall: 0.9035 - val_loss: 0.4411 - val_accuracy: 0.8987 - val_precision: 0.9230 - val_recall: 0.8718
#
# Epoch 00029: val_loss did not improve from 0.31638
# Epoch 30/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2588 - accuracy: 0.9215 - precision: 0.9391 - recall: 0.9051 - val_loss: 0.3975 - val_accuracy: 0.8947 - val_precision: 0.9208 - val_recall: 0.8718
#
# Epoch 00030: val_loss did not improve from 0.31638
# Epoch 31/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.2838 - accuracy: 0.9185 - precision: 0.9410 - recall: 0.8996 - val_loss: 0.3609 - val_accuracy: 0.8993 - val_precision: 0.9458 - val_recall: 0.8683
#
# Epoch 00031: val_loss did not improve from 0.31638
# Epoch 32/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2447 - accuracy: 0.9268 - precision: 0.9456 - recall: 0.9112 - val_loss: 0.3760 - val_accuracy: 0.9187 - val_precision: 0.9379 - val_recall: 0.9084
#
# Epoch 00032: val_loss did not improve from 0.31638
# Epoch 33/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.2326 - accuracy: 0.9288 - precision: 0.9474 - recall: 0.9154 - val_loss: 0.3201 - val_accuracy: 0.9187 - val_precision: 0.9417 - val_recall: 0.8964
#
# Epoch 00033: val_loss did not improve from 0.31638
# Epoch 34/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2167 - accuracy: 0.9326 - precision: 0.9493 - recall: 0.9188 - val_loss: 0.3586 - val_accuracy: 0.9073 - val_precision: 0.9301 - val_recall: 0.8907
#
# Epoch 00034: val_loss did not improve from 0.31638
# Epoch 35/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2062 - accuracy: 0.9366 - precision: 0.9500 - recall: 0.9250 - val_loss: 0.4142 - val_accuracy: 0.9010 - val_precision: 0.9204 - val_recall: 0.8872
#
# Epoch 00035: val_loss did not improve from 0.31638
# Epoch 36/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.2209 - accuracy: 0.9349 - precision: 0.9504 - recall: 0.9198 - val_loss: 0.3461 - val_accuracy: 0.9096 - val_precision: 0.9335 - val_recall: 0.8912
#
# Epoch 00036: val_loss did not improve from 0.31638
# Epoch 37/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2027 - accuracy: 0.9402 - precision: 0.9543 - recall: 0.9263 - val_loss: 0.3033 - val_accuracy: 0.9284 - val_precision: 0.9458 - val_recall: 0.9096
#
# Epoch 00037: val_loss improved from 0.31638 to 0.30328, saving model to .\audio_classification.hdf5
# Epoch 38/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.1837 - accuracy: 0.9449 - precision: 0.9584 - recall: 0.9341 - val_loss: 0.3861 - val_accuracy: 0.9113 - val_precision: 0.9386 - val_recall: 0.8930
#
# Epoch 00038: val_loss did not improve from 0.30328
# Epoch 39/50
# 219/219 [==============================] - 8s 39ms/step - loss: 0.1988 - accuracy: 0.9433 - precision: 0.9580 - recall: 0.9336 - val_loss: 0.3643 - val_accuracy: 0.9164 - val_precision: 0.9378 - val_recall: 0.8975
#
# Epoch 00039: val_loss did not improve from 0.30328
# Epoch 40/50
# 219/219 [==============================] - 8s 39ms/step - loss: 0.2582 - accuracy: 0.9310 - precision: 0.9457 - recall: 0.9205 - val_loss: 0.4515 - val_accuracy: 0.9084 - val_precision: 0.9420 - val_recall: 0.8741
#
# Epoch 00040: val_loss did not improve from 0.30328
# Epoch 41/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2140 - accuracy: 0.9366 - precision: 0.9497 - recall: 0.9248 - val_loss: 0.5373 - val_accuracy: 0.8941 - val_precision: 0.9177 - val_recall: 0.8741
#
# Epoch 00041: val_loss did not improve from 0.30328
# Epoch 42/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2351 - accuracy: 0.9363 - precision: 0.9519 - recall: 0.9258 - val_loss: 0.3675 - val_accuracy: 0.9113 - val_precision: 0.9333 - val_recall: 0.8975
#
# Epoch 00042: val_loss did not improve from 0.30328
# Epoch 43/50
# 219/219 [==============================] - 7s 34ms/step - loss: 0.1946 - accuracy: 0.9420 - precision: 0.9556 - recall: 0.9309 - val_loss: 0.3877 - val_accuracy: 0.9210 - val_precision: 0.9389 - val_recall: 0.9061
#
# Epoch 00043: val_loss did not improve from 0.30328
# Epoch 44/50
# 219/219 [==============================] - 9s 40ms/step - loss: 0.1760 - accuracy: 0.9457 - precision: 0.9594 - recall: 0.9366 - val_loss: 0.4506 - val_accuracy: 0.9010 - val_precision: 0.9250 - val_recall: 0.8901
#
# Epoch 00044: val_loss did not improve from 0.30328
# Epoch 45/50
# 219/219 [==============================] - 8s 38ms/step - loss: 0.2020 - accuracy: 0.9414 - precision: 0.9565 - recall: 0.9294 - val_loss: 0.4374 - val_accuracy: 0.9067 - val_precision: 0.9283 - val_recall: 0.8821
#
# Epoch 00045: val_loss did not improve from 0.30328
# Epoch 46/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.1928 - accuracy: 0.9419 - precision: 0.9536 - recall: 0.9301 - val_loss: 0.3886 - val_accuracy: 0.9050 - val_precision: 0.9299 - val_recall: 0.8890
#
# Epoch 00046: val_loss did not improve from 0.30328
# Epoch 47/50
# 219/219 [==============================] - 8s 37ms/step - loss: 0.2845 - accuracy: 0.9271 - precision: 0.9420 - recall: 0.9118 - val_loss: 0.3640 - val_accuracy: 0.9090 - val_precision: 0.9399 - val_recall: 0.8952
#
# Epoch 00047: val_loss did not improve from 0.30328
# Epoch 48/50
# 219/219 [==============================] - 8s 36ms/step - loss: 0.2016 - accuracy: 0.9432 - precision: 0.9593 - recall: 0.9310 - val_loss: 0.3709 - val_accuracy: 0.9147 - val_precision: 0.9385 - val_recall: 0.8998
#
# Epoch 00048: val_loss did not improve from 0.30328
# Epoch 49/50
# 219/219 [==============================] - 8s 39ms/step - loss: 0.1851 - accuracy: 0.9453 - precision: 0.9574 - recall: 0.9351 - val_loss: 0.3680 - val_accuracy: 0.9244 - val_precision: 0.9401 - val_recall: 0.9067
#
# Epoch 00049: val_loss did not improve from 0.30328
# Epoch 50/50
# 219/219 [==============================] - 8s 34ms/step - loss: 0.1879 - accuracy: 0.9456 - precision: 0.9580 - recall: 0.9370 - val_loss: 0.3791 - val_accuracy: 0.9176 - val_precision: 0.9381 - val_recall: 0.9015
#
# Epoch 00050: val_loss did not improve from 0.30328
# Training completed in time:  0:06:28.250334

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

# Check the Test Accuracy
test_accuracy=model.evaluate(X_test,y_test,verbose=1)
print(test_accuracy[1])
# Out:
# 55/55 [==============================] - 0s 8ms/step - loss: 0.3791 - accuracy: 0.9176 - precision: 0.9381 - recall: 0.9015
# 0.9175729751586914

# %%
os.environ["KERAS_BACKEND"] = "plaidml.keras.backend"

#model.predict_classes(X_test)
predict_x=model.predict(X_test)
classes_x=np.argmax(predict_x,axis=1)
print(classes_x)
# Out:
# [5 3 4 ... 1 2 2]

# %% [markdown]
# # Metric Visualization

# %%
# summarize history for accuracy

plt.subplot(211)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='lower right')

# summarize history for loss

plt.subplot(212)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')

plt.tight_layout()

plt.show()

# %%
import scikitplot as skplt

# convert tests labels in single-digits instead of one-hot encoding!
y_test_arg=np.argmax(y_test,axis=1)
skplt.metrics.plot_confusion_matrix(y_test_arg, classes_x, normalize=False, title = 'Confusion Matrix for CAC w/o norm')
# Out:
# <AxesSubplot: title={'center': 'Confusion Matrix for CAC w/o norm'}, xlabel='Predicted label', ylabel='True label'>

# %%
skplt.metrics.plot_confusion_matrix(y_test_arg, classes_x, normalize=True, title = 'Confusion Matrix for CAC with norm')
# Out:
# <AxesSubplot: title={'center': 'Confusion Matrix for CAC with norm'}, xlabel='Predicted label', ylabel='True label'>

# %%
plt.figure(figsize = (18,8))
sns.heatmap(metrics.confusion_matrix(y_test_arg, classes_x, normalize='true'), annot = True, cmap = 'plasma')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
